# %% [markdown]
# ### Preparing the Dataset
# Following small dataset is a classic example used in Andrew Ng’s Machine Learning course.

# %%
import pandas as pd
from io import StringIO

# Raw data as a multiline string
data = """2104,3,399900
1600,3,329900
2400,3,369000
1416,2,232000
3000,4,539900
1985,4,299900
1534,3,314900
1427,3,198999
1380,3,212000
1494,3,242500
1940,4,239999
2000,3,347000
1890,3,329999
4478,5,699900
1268,3,259900
2300,4,449900
1320,2,299900
1236,3,199900
2609,4,499998
3031,4,599000
1767,3,252900
1888,2,255000
1604,3,242900
1962,4,259900
3890,3,573900
1100,3,249900
1458,3,464500
2526,3,469000
2200,3,475000
2637,3,299900
1839,2,349900
1000,1,169900
2040,4,314900
3137,3,579900
1811,4,285900
1437,3,249900
1239,3,229900
2132,4,345000
4215,4,549000
2162,4,287000
1664,2,368500
2238,3,329900
2567,4,314000
1200,3,299000
852,2,179900
1852,4,299900
1203,3,239500"""

# Define column names
columns = ['Size', 'Bedrooms', 'Price']

# Read the string as if it were a CSV
df = pd.read_csv(StringIO(data), header=None, names=columns)

# Save to CSV
df.to_csv('house_data.csv', index=False)

# Display the dataframe
print(df)

# %% [markdown]
# ### Plot the housing price

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Sample dataset
house_data = pd.read_csv('./house_data.csv')

# Convert to DataFrame
df = pd.DataFrame(house_data)

# Fit linear regression (Size vs Price)
slope, intercept = np.polyfit(df['Size'], df['Price'], 1)
regression_line = slope * np.array(df['Size']) + intercept

# Plot setup
plt.figure(figsize=(8, 5))
plt.scatter(df['Size'], df['Price'], color='red', label='Data Points')

# Plot regression line
plt.plot(df['Size'], regression_line, color='royalblue', linewidth=2, label='Regression Line')

# ----  Labels and Title  ----
# Format y-axis ticks as '100k', '200k', etc.

def thousands_formatter(x, pos):
    return f'{int(x/1000)}'
# x : is the tick value being formatted (like 700000, 400000, etc.).
# pos : is the tick position index along the axis.
# pos=0 for the first tick
# pos=1 for the second tick
# Even if you don’t use pos inside the function, matplotlib always passes it because the formatter function needs to accept two arguments by design.


plt.gca().yaxis.set_major_formatter(FuncFormatter(thousands_formatter))

plt.xlabel('Size (sq ft)')
plt.ylabel('Price (1000 USD)')
plt.title('Housing Prices')

# Legend
plt.legend()

# Modern-minimal style tweaks
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()

# Save as vector file (SVG or PDF are good choices)
plt.savefig('house_price_plot.svg')    # or .pdf / .eps

# Show plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample dataset
house_data = pd.read_csv('./house_data.csv')

# Convert to DataFrame
df = pd.DataFrame(house_data)

# %%
df
# Out:
#     Size  Bedrooms   Price
# 0   2104         3  399900
# 1   1600         3  329900
# 2   2400         3  369000
# 3   1416         2  232000
# 4   3000         4  539900
# 5   1985         4  299900
# 6   1534         3  314900
# 7   1427         3  198999
# 8   1380         3  212000
# 9   1494         3  242500
# 10  1940         4  239999
# 11  2000         3  347000
# 12  1890         3  329999
# 13  4478         5  699900
# 14  1268         3  259900
# 15  2300         4  449900
# 16  1320         2  299900
# 17  1236         3  199900
# 18  2609         4  499998
# 19  3031         4  599000
# 20  1767         3  252900
# 21  1888         2  255000
# 22  1604         3  242900
# 23  1962         4  259900
# 24  3890         3  573900
# 25  1100         3  249900
# 26  1458         3  464500
# 27  2526         3  469000
# 28  2200         3  475000
# 29  2637         3  299900
# 30  1839         2  349900
# 31  1000         1  169900
# 32  2040         4  314900
# ...
